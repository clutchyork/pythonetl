# %%
from __future__ import print_function

# %%
import requests as r
from bs4 import BeautifulSoup

# %%
res = r.get('http://news.nationalgeographic.com/bin/services/news/public/query/content.json?pageSize=100&offset=0&page=0&contentTypes=news/components/pagetypes/story/article,news/components/pagetypes/story/gallery')

# %%
# 把json轉換成dict
data = res.json()

# %%
print(data[0]['leadMedia'].keys())
print(data[0]['page'].keys())
# Out:
# [u'altText', u'url', u'isVideo', u'height', u'width', u'internal', u'aspectRatio']
# [u'sponsorContentLabel', u'title', u'url', u'abstract', u'publishDate', u'sponsored', u'type']

# %%
data[0]
# Out:
# {u'leadMedia': {u'altText': u'Illustration of a dwarf planet',
#   u'aspectRatio': 0.5625,
#   u'height': 1152,
#   u'internal': True,
#   u'isVideo': False,
#   u'url': u'http://news.nationalgeographic.com/content/dam/news/2016/07/12/01-dwarf-planet-neptune.ngsversion.1468354915168.jpg',
#   u'width': 2048},
#  u'page': {u'abstract': u'The icy world orbits the sun every 700 years\u2014and is among the 10 biggest unnamed objects in the outer solar system.',
#   u'publishDate': u'Tue Jul 12 16:21:00 EDT 2016',
#   u'sponsorContentLabel': u'Sponsor Content',
#   u'sponsored': False,
#   u'title': u'Why We Missed This Nearby Mini-Planet for So Long',
#   u'type': u'story/article',
#   u'url': u'http://news.nationalgeographic.com/2016/07/mini-pluto-dwarf-planet-discovery-astronomy.html'}}

# %%
from pymongo import MongoClient, ASCENDING

# %%
# client = MongoClient('mongodb://myusername:mypssword@localhost:27017/')
client = MongoClient('mongodb://localhost:27017/')

# %%
db = client['natgeo'] # 創建資料庫
articles = db.articles # 創建Collection

# %%
articles.insert({'title': "ok"})
# Out:
# /Users/ian/.pyenv/versions/2.7.11/lib/python2.7/site-packages/ipykernel/__main__.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   if __name__ == '__main__':
# ObjectId('5785a68f67e6e23dd1a0b2cb')

# %%
article_id = articles.insert_one(data[0])

# %%
article_id.inserted_id
# Out:
# ObjectId('57859a8b67e6e23dd1a0b267')

# %%
db.collection_names(include_system_collections=False)
# Out:
# [u'articles']

# %%
articles.find_one()
# Out:
# {u'_id': ObjectId('57856d7096ed6203dc5a99f3'),
#  u'abstract': u'The icy world orbits the sun every 700 years\u2014and is among the 10 biggest unnamed objects in the outer solar system.',
#  u'altText': u'Illustration of a dwarf planet',
#  u'aspectRatio': 0.5625,
#  u'height': 1152.0,
#  u'internal': True,
#  u'isVideo': False,
#  u'leadMedia_url': u'http://news.nationalgeographic.com/content/dam/news/2016/07/12/01-dwarf-planet-neptune.ngsversion.1468354915168.jpg',
#  u'page_url': u'http://news.nationalgeographic.com/2016/07/mini-pluto-dwarf-planet-discovery-astronomy.html',
#  u'publishDate': datetime.datetime(2016, 7, 12, 16, 21),
#  u'series': nan,
#  u'sponsorContentLabel': u'Sponsor Content',
#  u'sponsored': False,
#  u'title': u'Why We Missed This Nearby Mini-Planet for So Long',
#  u'titleText': nan,
#  u'type': u'story/article',
#  u'width': 2048.0}

# %%
articles.find_one({'page.title': 'Why We Missed This Nearby Mini-Planet for So Long'})
# Out:
# {u'_id': ObjectId('57856d7096ed6203dc5a99f3'),
#  u'abstract': u'The icy world orbits the sun every 700 years\u2014and is among the 10 biggest unnamed objects in the outer solar system.',
#  u'altText': u'Illustration of a dwarf planet',
#  u'aspectRatio': 0.5625,
#  u'height': 1152.0,
#  u'internal': True,
#  u'isVideo': False,
#  u'leadMedia_url': u'http://news.nationalgeographic.com/content/dam/news/2016/07/12/01-dwarf-planet-neptune.ngsversion.1468354915168.jpg',
#  u'page_url': u'http://news.nationalgeographic.com/2016/07/mini-pluto-dwarf-planet-discovery-astronomy.html',
#  u'publishDate': datetime.datetime(2016, 7, 12, 16, 21),
#  u'series': nan,
#  u'sponsorContentLabel': u'Sponsor Content',
#  u'sponsored': False,
#  u'title': u'Why We Missed This Nearby Mini-Planet for So Long',
#  u'titleText': nan,
#  u'type': u'story/article',
#  u'width': 2048.0}

# %%
from bson.objectid import ObjectId
document = articles.find_one({'_id': ObjectId('57859c0d67e6e23dd1a0b268')})
document
# Out:
# {u'_id': ObjectId('57859c0d67e6e23dd1a0b268'),
#  u'leadMedia': {u'altText': u'Picture of destroyed coral in South China Sea',
#   u'aspectRatio': 0.75,
#   u'height': 1536,
#   u'internal': True,
#   u'isVideo': False,
#   u'url': u'http://news.nationalgeographic.com/content/dam/news/2016/06/03/giantclam/01-claim-poaching-asia.ngsversion.1468353600997.jpg',
#   u'width': 2048},
#  u'page': {u'abstract': u'A new analysis of satellite imagery shows extensive coral reef damage in the South China Sea for the first time.',
#   u'publishDate': u'Tue Jul 12 15:51:38 EDT 2016',
#   u'series': u'Wildlife Watch',
#   u'sponsorContentLabel': u'Sponsor Content',
#   u'sponsored': False,
#   u'title': u'Giant Clam Poaching Wipes Out Reefs in South China Sea',
#   u'type': u'story/article',
#   u'url': u'http://news.nationalgeographic.com/2016/06/south-china-sea-coral-reef-destruction.html'}}

# %%
db.drop_collection('articles')

# %%
res = articles.insert_many(data)

# %%
res.inserted_ids
# Out:
# [ObjectId('57859a8b67e6e23dd1a0b267'),
#  ObjectId('57859c0d67e6e23dd1a0b268'),
#  ObjectId('57859c0d67e6e23dd1a0b269'),
#  ObjectId('57859c0d67e6e23dd1a0b26a'),
#  ObjectId('57859c0d67e6e23dd1a0b26b'),
#  ObjectId('57859c0d67e6e23dd1a0b26c'),
#  ObjectId('57859c0d67e6e23dd1a0b26d'),
#  ObjectId('57859c0d67e6e23dd1a0b26e'),
#  ObjectId('57859c0d67e6e23dd1a0b26f'),
#  ObjectId('57859c0d67e6e23dd1a0b270'),
#  ObjectId('57859c0d67e6e23dd1a0b271'),
#  ObjectId('57859c0d67e6e23dd1a0b272'),
#  ObjectId('57859c0d67e6e23dd1a0b273'),
#  ObjectId('57859c0d67e6e23dd1a0b274'),
#  ObjectId('57859c0d67e6e23dd1a0b275'),
#  ObjectId('57859c0d67e6e23dd1a0b276'),
#  ObjectId('57859c0d67e6e23dd1a0b277'),
#  ObjectId('57859c0d67e6e23dd1a0b278'),
#  ObjectId('57859c0d67e6e23dd1a0b279'),
#  ObjectId('57859c0d67e6e23dd1a0b27a'),
#  ObjectId('57859c0d67e6e23dd1a0b27b'),
#  ObjectId('57859c0d67e6e23dd1a0b27c'),
#  ObjectId('57859c0d67e6e23dd1a0b27d'),
#  ObjectId('57859c0d67e6e23dd1a0b27e'),
# ...

# %%
articles.find_one({'page.series': 'Wildlife Watch'})
# Out:
# {u'_id': ObjectId('57859c0d67e6e23dd1a0b268'),
#  u'leadMedia': {u'altText': u'Picture of destroyed coral in South China Sea',
#   u'aspectRatio': 0.75,
#   u'height': 1536,
#   u'internal': True,
#   u'isVideo': False,
#   u'url': u'http://news.nationalgeographic.com/content/dam/news/2016/06/03/giantclam/01-claim-poaching-asia.ngsversion.1468353600997.jpg',
#   u'width': 2048},
#  u'page': {u'abstract': u'A new analysis of satellite imagery shows extensive coral reef damage in the South China Sea for the first time.',
#   u'publishDate': u'Tue Jul 12 15:51:38 EDT 2016',
#   u'series': u'Wildlife Watch',
#   u'sponsorContentLabel': u'Sponsor Content',
#   u'sponsored': False,
#   u'title': u'Giant Clam Poaching Wipes Out Reefs in South China Sea',
#   u'type': u'story/article',
#   u'url': u'http://news.nationalgeographic.com/2016/06/south-china-sea-coral-reef-destruction.html'}}

# %%
#articles.find()
for article in articles.find({'page.series': 'Wildlife Watch'}):
    print(article['page']['series'])
# Out:
# Wildlife Watch
# Wildlife Watch
# Wildlife Watch
# Wildlife Watch
# Wildlife Watch
# Wildlife Watch
# Wildlife Watch
# Wildlife Watch
# Wildlife Watch
# Wildlife Watch
# Wildlife Watch
# Wildlife Watch

# %%
articles.find({'page.series': 'Wildlife Watch'}).count()
# Out:
# 12

# %%
db.drop_collection('articles')

# %%
client.drop_database('natgeo')

# %%
db.collection_names(include_system_collections=False)
# Out:
# []

# %%
result = articles.create_index([('page.url', ASCENDING)], unique=True)

# %%
list(articles.index_information())
# Out:
# [u'_id_', u'page.url_1']

# %% [markdown]
# ## 進階query:
# https://docs.mongodb.com/manual/reference/operator/query/

# %%
for article in articles.find({'leadMedia.height': {"$lt": 1500}}):
    print(article['leadMedia']['height'], article['page']['title'])
# Out:
# 1152 Why We Missed This Nearby Mini-Planet for So Long
# 529 Why an Eagle Really Grabbed a Kid
# 547 Good News for Cougars: More Kittens Found Near Big City
# 1365 City Cemetery Is Alive With Shocking Number of Bats, Spiders
# 1365 This Week’s Night Sky: Watch the Moon Meet Mars
# 1481 See Young Lion Yank Tranquilizer Dart out of Lioness
# 1365 Scary New Superbug Is Popping Up in More Places
# 1365 How Archaeologists Discovered 23 Shipwrecks in 22 Days
# 1365 New, Massive Earthquake Threat Could Lurk Under South Asia
# 1365 Black Market Caviar Threatens California's Giant Fish
# 1365 Tiger Got Your Goat? Here's Who to Call
# 1365 Nearly 2,000 Pounds of Illegal Shark Fins Found in Cargo
# 1365 How Dad and Daughter Survived the Alaskan Wilderness
# 1381 Discovery of Philistine Cemetery May Solve Biblical Mystery
# 1334 Geckos May Be Famously Sticky, but Here's What Stumps Them
# 1365 This Week @NatGeo
# 1361 Antique Dealers Come Face to Face With Ivory Ban
# ...

# %%
client.close()

# %%
client.server_info()
# Out:
# {u'allocator': u'system',
#  u'bits': 64,
#  u'buildEnvironment': {u'cc': u'/usr/bin/clang: Apple LLVM version 7.3.0 (clang-703.0.31)',
#   u'ccflags': u'-I/usr/local/opt/openssl/include -fno-omit-frame-pointer -fPIC -fno-strict-aliasing -ggdb -pthread -Wall -Wsign-compare -Wno-unknown-pragmas -Winvalid-pch -O2 -Wno-unused-local-typedefs -Wno-unused-function -Wno-unused-private-field -Wno-deprecated-declarations -Wno-tautological-constant-out-of-range-compare -Wno-unused-const-variable -Wno-missing-braces -Wno-inconsistent-missing-override -Wno-potentially-evaluated-expression -Wno-null-conversion -mmacosx-version-min=10.11 -fno-builtin-memcmp',
#   u'cxx': u'/usr/bin/clang++: Apple LLVM version 7.3.0 (clang-703.0.31)',
#   u'cxxflags': u'-Wnon-virtual-dtor -Woverloaded-virtual -Wpessimizing-move -Wredundant-move -std=c++11',
#   u'distarch': u'x86_64',
#   u'distmod': u'',
#   u'linkflags': u'-L/usr/local/opt/openssl/lib -fPIC -pthread -Wl,-bind_at_load -mmacosx-version-min=10.11',
# ...

# %% [markdown]
# ## MySQL
# - pip install mysql-python OR
# - conda install mysql-python

# %%
import MySQLdb

# %%
# MySQLdb.connect(host, username, password, "test_db")
db = MySQLdb.connect("localhost", "root", db = "test_db")

# %%
cursor = db.cursor()

# %%
cursor.execute("DROP TABLE IF EXISTS ARTICLES")
# Out:
# 0L

# %%
sql = """CREATE TABLE articles (
         title varchar(255),
         page_url varchar(255),
         cover_url varchar(255),
         image_height int)"""

# %%
cursor.execute(sql)
# Out:
# 0L

# %%
title = "my book"
page_url = "https://google.com"
cover_url = "https://google.com"
image_height = 1500

sql = """INSERT INTO articles(
      title,
      page_url,
      cover_url,
      image_height
      )
      VALUES ('%s', '%s', '%s', '%d')"""\
      % (title, page_url, cover_url, image_height)
print(sql)
try:
# Execute the SQL command
   cursor.execute(sql)
# cursor.executemany(sql, list_of_tuples)
# Commit your changes in the database
   db.commit()
except:
# Rollback in case there is any error
   db.rollback()

# disconnect from server
db.close()
# Out:
# INSERT INTO articles(
#       title,
#       page_url,
#       cover_url,
#       image_height
#       )
#       VALUES ('my book', 'https://google.com', 'https://google.com', '1500')

# %%
title = "my book"
page_url = "https://google.com"
cover_url = "https://google.com"
image_height = 1500
list_of_tuples = []
for x in range(1,101):
    data = (title, page_url, cover_url, image_height + x)
    #print(data)
    list_of_tuples.append(data)
print(data_list) # list of tuples
print(type(list_of_tuples))
# Out:
# [('my book', 'https://google.com', 'https://google.com', 1501), ('my book', 'https://google.com', 'https://google.com', 1502), ('my book', 'https://google.com', 'https://google.com', 1503), ('my book', 'https://google.com', 'https://google.com', 1504), ('my book', 'https://google.com', 'https://google.com', 1505), ('my book', 'https://google.com', 'https://google.com', 1506), ('my book', 'https://google.com', 'https://google.com', 1507), ('my book', 'https://google.com', 'https://google.com', 1508), ('my book', 'https://google.com', 'https://google.com', 1509), ('my book', 'https://google.com', 'https://google.com', 1510), ('my book', 'https://google.com', 'https://google.com', 1511), ('my book', 'https://google.com', 'https://google.com', 1512), ('my book', 'https://google.com', 'https://google.com', 1513), ('my book', 'https://google.com', 'https://google.com', 1514), ('my book', 'https://google.com', 'https://google.com', 1515), ('my book', 'https://google.com', 'https://google.co
# ...

# %%
db = MySQLdb.connect("localhost", "root", db = "test_db")
cursor = db.cursor()
sql = """INSERT INTO articles(
      title,
      page_url,
      cover_url,
      image_height
      )
      VALUES (%s, %s, %s, %s)"""#\
      #% (title, page_url, cover_url, image_height)
print(sql)
try:
# Execute the SQL command
#cursor.execute(sql)
    cursor.executemany(sql, list_of_tuples) # 自動置換template內的變數
# Commit your changes in the database
    db.commit()
except Exception as e:
# Rollback in case there is any error
    print(e)   
    db.rollback()

# disconnect from server
db.close()
# Out:
# INSERT INTO articles(
#       title,
#       page_url,
#       cover_url,
#       image_height
#       )
#       VALUES (%s, %s, %s, %s)

# %% [markdown]
# ## Pandas
# - https://github.com/dlab-berkeley/introduction-to-pandas/blob/master/introduction-to-pandas-2.4.1.ipynb
# - https://github.com/fonnesbeck/Bios8366/blob/master/notebooks/Section2_5-Introduction-to-Pandas.ipynb

# %%
import pandas as pd

# %%
res = r.get('http://news.nationalgeographic.com/bin/services/news/public/query/content.json?pageSize=100&offset=0&page=0&contentTypes=news/components/pagetypes/story/article,news/components/pagetypes/story/gallery')

# %%
data = res.json()

# %%
# 原始dict結構
data[0]
# Out:
# {u'leadMedia': {u'altText': u'Illustration of a dwarf planet',
#   u'aspectRatio': 0.5625,
#   u'height': 1152,
#   u'internal': True,
#   u'isVideo': False,
#   u'url': u'http://news.nationalgeographic.com/content/dam/news/2016/07/12/01-dwarf-planet-neptune.ngsversion.1468354915168.jpg',
#   u'width': 2048},
#  u'page': {u'abstract': u'The icy world orbits the sun every 700 years\u2014and is among the 10 biggest unnamed objects in the outer solar system.',
#   u'publishDate': u'Tue Jul 12 16:21:00 EDT 2016',
#   u'sponsorContentLabel': u'Sponsor Content',
#   u'sponsored': False,
#   u'title': u'Why We Missed This Nearby Mini-Planet for So Long',
#   u'type': u'story/article',
#   u'url': u'http://news.nationalgeographic.com/2016/07/mini-pluto-dwarf-planet-discovery-astronomy.html'}}

# %%
pd.DataFrame(data)
# Out:
#                                             leadMedia  \
# 0   {u'altText': u'Illustration of a dwarf planet'...
# 1   {u'altText': u'Picture of destroyed coral in S...
# 2   {u'url': u'http://news.nationalgeographic.com/...
# 3   {u'url': u'http://news.nationalgeographic.com/...
# 4   {u'altText': u'Picture of Weissensee Cemetery'...
# 5   {u'altText': u'Picture of coral', u'url': u'ht...
# 6   {u'altText': u'Picture of the Mars Curiosity R...
# 7   {u'altText': u'Picture of young lion attempts ...
# 8   {u'altText': u'picture of e.coli bacteria', u'...
# 9   {u'altText': u'Picture of a person inspecting ...
# 10  {u'altText': u'Picture of Dhaka', u'url': u'ht...
# 11  {u'url': u'http://news.nationalgeographic.com/...
# 12  {u'altText': u'Picture of a white sturgeon swi...
# 13  {u'altText': u'Picture of a woman standing amo...
# 14  {u'altText': u'Picture of activist protesting ...
# 15  {u'altText': u'Picture of rafters float down t...
# ...

# %%
from pandas.io.json import json_normalize
flat_data = json_normalize(data)
flat_data
# Out:
#                                     leadMedia.altText  leadMedia.aspectRatio  \
# 0                      Illustration of a dwarf planet               0.562500
# 1       Picture of destroyed coral in South China Sea               0.750000
# 2                                                 NaN               0.801515
# 3                                                 NaN               0.728362
# 4                      Picture of Weissensee Cemetery               0.666504
# 5                                    Picture of coral               0.750000
# 6                 Picture of the Mars Curiosity Rover               0.666504
# 7   Picture of young lion attempts to pull out a t...               0.723145
# 8                          picture of e.coli bacteria               0.666504
# 9   Picture of a person inspecting a shipwreck und...               0.666504
# 10                                   Picture of Dhaka               0.666504
# ...

# %%
# from pandas.io.json import json_normalize
# flat_data = json_normalize(data)
# df = pd.DataFrame(flat_data) # 創建DataFrame
df = flat_data
df.rename(columns={'leadMedia.url': '.leadMedia_url', 'page.url': '.page_url'}, inplace=True)
df.rename(columns=lambda x: x.split('.')[1], inplace=True)
df.rename(columns={'height': 'price'}, inplace=True)
df
# Out:
#                                               altText  aspectRatio   price  \
# 0                      Illustration of a dwarf planet     0.562500  1152.0
# 1       Picture of destroyed coral in South China Sea     0.750000  1536.0
# 2                                                 NaN     0.801515   529.0
# 3                                                 NaN     0.728362   547.0
# 4                      Picture of Weissensee Cemetery     0.666504  1365.0
# 5                                    Picture of coral     0.750000  1536.0
# 6                 Picture of the Mars Curiosity Rover     0.666504  1365.0
# 7   Picture of young lion attempts to pull out a t...     0.723145  1481.0
# 8                          picture of e.coli bacteria     0.666504  1365.0
# 9   Picture of a person inspecting a shipwreck und...     0.666504  1365.0
# 10                                   Picture of Dhaka     0.666504  1365.0
# ...

# %%
print(df.shape) # (行數, 列數)
print(df.describe()) # DataFrame的統計資料
# Out:
# (100, 16)
#        aspectRatio        price        width
# count    95.000000    95.000000    95.000000
# mean      0.703612  1447.126316  2058.263158
# std       0.143845   527.539920   564.500536
# min       0.489224   227.000000   386.000000
# 25%            NaN          NaN          NaN
# 50%            NaN          NaN          NaN
# 75%            NaN          NaN          NaN
# max       1.500366  4778.000000  5616.000000

# %%
df.head(5) # 取前x行
# Out:
#                                          altText  aspectRatio   price  \
# 0                 Illustration of a dwarf planet     0.562500  1152.0
# 1  Picture of destroyed coral in South China Sea     0.750000  1536.0
# 2                                            NaN     0.801515   529.0
# 3                                            NaN     0.728362   547.0
# 4                 Picture of Weissensee Cemetery     0.666504  1365.0
#
#   internal isVideo titleText  \
# 0     True   False       NaN
# 1     True   False       NaN
# 2     True   False       NaN
# 3     True   False       NaN
# 4     True   False       NaN
#
#                                        leadMedia_url   width  \
# 0  http://news.nationalgeographic.com/content/dam...  2048.0
# 1  http://news.nationalgeographic.com/content/dam...  2048.0
# 2  http://news.nationalgeographic.com/content/dam...   660.0
# 3  http://news.nationalgeographic.com/content/dam...   751.0
# ...

# %%
df['publishDate'].head() # type <Series>
# Out:
# 0    Tue Jul 12 16:21:00 EDT 2016
# 1    Tue Jul 12 15:51:38 EDT 2016
# 2    Tue Jul 12 15:47:00 EDT 2016
# 3    Tue Jul 12 15:11:00 EDT 2016
# 4    Tue Jul 12 14:44:38 EDT 2016
# Name: publishDate, dtype: object

# %% [markdown]
# ## DataFrame的操作都是以column為單位

# %%
datetime_df = df['publishDate'].str.replace(r' [A-Z]{3} ', ' ')
datetime_df.head()
# Out:
# 0    Tue Jul 12 16:21:00 2016
# 1    Tue Jul 12 15:51:38 2016
# 2    Tue Jul 12 15:47:00 2016
# 3    Tue Jul 12 15:11:00 2016
# 4    Tue Jul 12 14:44:38 2016
# Name: publishDate, dtype: object

# %%
df['pub_datetime'] = pd.to_datetime(datetime_df) + pd.Timedelta('4 hours')

# %%
df['pub_datetime'].head()
# Out:
# 0   2016-07-12 20:21:00
# 1   2016-07-12 19:51:38
# 2   2016-07-12 19:47:00
# 3   2016-07-12 19:11:00
# 4   2016-07-12 18:44:38
# Name: pub_datetime, dtype: datetime64[ns]

# %%
print(df['price'].sum())
print(df['price'].mean())
print(df['price'].min())
print(df['price'].max())
# Out:
# 137477.0
# 1447.12631579
# 227.0
# 4778.0

# %%
df.query('width > 660.0 & series == "Wildlife Watch"' ).sort_values('price', ascending=False)
# Out:
#                                               altText  aspectRatio   price  \
# 1       Picture of destroyed coral in South China Sea     0.750000  1536.0
# 79                       Picture of loggerhead turtle     0.750000  1536.0
# 12  Picture of a white sturgeon swimming in green ...     0.666504  1365.0
# 14     Picture of activist protesting shark fin trade     0.666504  1365.0
# 39                                                NaN     0.666504  1365.0
# 43             Picture of confiscated dried seahorses     0.666504  1365.0
# 69                                                NaN     0.666504  1365.0
# 73   Picture of a dead pangolin in Sumatra, Indonesia     0.666504  1365.0
# 87                                                NaN     0.666504  1365.0
# 54  Picture of Cecil the lion, a few weeks before ...     0.665527  1363.0
# 19              Picture of An elephant ivory pendant      0.666503  1361.0
# ...

# %%
from sqlalchemy import create_engine

# %%
# mysql://username:password@host:port/database
engine = create_engine('mysql://root@localhost/test_db')

# 如果有Latin-1的編碼問題，
# engine = create_engine('mysql://root@localhost/test_db?charset=utf8')

# %%
# ?df.to_sql

# %%
df.to_sql('natgeo', engine, if_exists='replace') # to_sql(table_name, databse_conn)

# %%
df.to_dict()
# Out:
# {'abstract': {0: u'The icy world orbits the sun every 700 years\u2014and is among the 10 biggest unnamed objects in the outer solar system.',
#   1: u'A new analysis of satellite imagery shows extensive coral reef damage in the South China Sea for the first time.',
#   2: u"A photograph of a huge bird of prey grabbing on to a boy's head has gone viral\u2014here are possible reasons for its behavior.",
#   3: u'Two new litters tucked away in the Santa Susana Mountains are a positive sign for the population, which live not far from Los Angeles.',
#   4: u'A huge new survey shows that a historic Jewish cemetery in Berlin is now a haven for hundreds of creatures normally found in the deep woods.',
#   5: u'New underwater microscope gives scientists an extreme close-up of life in a reef.',
#   6: u'Also this week, a meteor shower will start to sprinkle and Saturn will shine near the lunar disk.',
#   7: u'Was this heroic behavior or merely cat curiosity? A big cat expert explains.',
# ...

# %%
df.to_dict('records')
# Out:
# [{'abstract': u'The icy world orbits the sun every 700 years\u2014and is among the 10 biggest unnamed objects in the outer solar system.',
#   'altText': u'Illustration of a dwarf planet',
#   'aspectRatio': 0.5625,
#   'internal': True,
#   'isVideo': False,
#   'leadMedia_url': u'http://news.nationalgeographic.com/content/dam/news/2016/07/12/01-dwarf-planet-neptune.ngsversion.1468354915168.jpg',
#   'page_url': u'http://news.nationalgeographic.com/2016/07/mini-pluto-dwarf-planet-discovery-astronomy.html',
#   'price': 1152.0,
#   'pub_datetime': Timestamp('2016-07-12 20:21:00'),
#   'publishDate': u'Tue Jul 12 16:21:00 EDT 2016',
#   'series': nan,
#   'sponsorContentLabel': u'Sponsor Content',
#   'sponsored': False,
#   'title': u'Why We Missed This Nearby Mini-Planet for So Long',
#   'titleText': nan,
#   'type': u'story/article',
#   'width': 2048.0},
# ...

# %%
myuni = u'你好'
mystr = '你好'
print(type(myuni))
print(type(mystr))
# Out:
# <type 'unicode'>
# <type 'str'>

# %%
myunilist = [myuni]
mystrlist = [mystr]

# %%
print(type(myunilist[0]))
print(myunilist[0])
print(myunilist)
# Out:
# <type 'unicode'>
# 你好
# [u'\u4f60\u597d']

# %%
print(type(mystrlist[0]))
print(mystrlist[0])
print(mystrlist)
# Out:
# <type 'str'>
# 你好
# ['\xe4\xbd\xa0\xe5\xa5\xbd']
